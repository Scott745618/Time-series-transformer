# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline

from scipy.interpolate import CubicSpline
# Out:
# C:\Users\SGrah\anaconda3\lib\site-packages\scipy\__init__.py:138: UserWarning: A NumPy version >=1.16.5 and <1.23.0 is required for this version of SciPy (detected version 1.24.4)
#   warnings.warn(f"A NumPy version >={np_minversion} and <{np_maxversion} is required for this version of "

# %%
path = r'C:\Users\SGrah\OneDrive\Documents\Scott\Masters\Thesis\Data\GDP data Sep-21.csv'

df = pd.read_csv(path, header=0, usecols=[0,1,2,3,4,5,6,7], nrows=112, index_col=[0])
df
# Out:
#            NZ  Unemployment  CPI  Export prices  Import prices  HPI   OICR
# Year-Qtr
# Mar-90    0.2           7.2  7.2           -0.2           -0.4  2.1  13.45
# Jun-90   -0.5           7.7  7.0           -2.7            0.7  0.7  13.25
# Sep-90   -0.3           8.1  7.6           -2.3           -2.1  0.6  13.96
# Dec-90    0.0           8.9  5.0            0.8            6.8 -0.2  13.01
# Mar-91    0.2           9.8  4.9           -3.1           -1.6 -0.6  11.76
# ...       ...           ...  ...            ...            ...  ...    ...
# Dec-16    4.0           5.3  0.4            4.9           -0.9  0.9   1.77
# Mar-17    3.8           4.9  1.3            6.9            2.9  1.5   1.68
# Jun-17    3.6           4.8  2.2            2.2            1.3  0.2   1.67
# Sep-17    3.4           4.6  1.7           -1.7           -2.9  1.1   1.64
# Dec-17    3.5           4.5  1.9            5.5            3.9  1.1   1.64
#
# [112 rows x 7 columns]

# %%
conda update --all
# Out:
# Collecting package metadata (current_repodata.json): ...working... done
# Solving environment: ...working... done
#
# ## Package Plan ##
#
#   environment location: C:\Users\SGrah\anaconda3
#
#
# The following packages will be downloaded:
#
#     package                    |            build
#     ---------------------------|-----------------
#     conda-env-2.6.0            |       haa95532_1           3 KB
#     navigator-updater-0.5.1    |   py38haa95532_0         2.3 MB
#     xmltodict-0.12.0           |     pyhd3eb1b0_0          13 KB
#     ------------------------------------------------------------
#                                            Total:         2.3 MB
#
# The following packages will be UPDATED:
#
#   navigator-updater                            0.2.1-py38_0 --> 0.5.1-py38haa95532_0
#
# The following packages will be DOWNGRADED:
#
#   conda-env                                         2.6.0-1 --> 2.6.0-haa95532_1
#   xmltodict                                     0.12.0-py_0 --> 0.12.0-pyhd3eb1b0_0
#
#
#
# Downloading and Extracting Packages
#
# conda-env-2.6.0      | 3 KB      |            |   0%
# conda-env-2.6.0      | 3 KB      | ########## | 100%
# conda-env-2.6.0      | 3 KB      | ########## | 100%
#
# navigator-updater-0. | 2.3 MB    |            |   0%
# navigator-updater-0. | 2.3 MB    |            |   1%
# navigator-updater-0. | 2.3 MB    | 2          |   2%
# navigator-updater-0. | 2.3 MB    | 4          |   4%
# navigator-updater-0. | 2.3 MB    | 8          |   9%
# navigator-updater-0. | 2.3 MB    | #4         |  14%
# navigator-updater-0. | 2.3 MB    | ##3        |  23%
# navigator-updater-0. | 2.3 MB    | ###6       |  36%
# navigator-updater-0. | 2.3 MB    | #####      |  51%
# navigator-updater-0. | 2.3 MB    | #######1   |  71%
# navigator-updater-0. | 2.3 MB    | ########## | 100%
# navigator-updater-0. | 2.3 MB    | ########## | 100%
#
# xmltodict-0.12.0     | 13 KB     |            |   0%
# xmltodict-0.12.0     | 13 KB     | ########## | 100%
# xmltodict-0.12.0     | 13 KB     | ########## | 100%
# Preparing transaction: ...working... done
# Verifying transaction: ...working... done
# Executing transaction: ...working... done
#
# Note: you may need to restart the kernel to use updated packages.
# ==> WARNING: A newer version of conda exists. <==
#   current version: 4.10.1
#   latest version: 25.7.0
#
# Please update conda by running
#
#     $ conda update -n base -c defaults conda
