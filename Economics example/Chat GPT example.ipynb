# %%
train_dataset = Dataset_Custom(
    root_path='./',                 # folder path
    data_path='econ.csv',           # your file with 333 rows
    size=[36, 12, 24],              # 3 years in encoder, 1 year in labels, predict 24 months ahead
    features='MS',                  # use all inputs but forecast only OT
    target='OT',
    scale=True,
    inverse=False,
    timeenc=1,
    freq='m'
)
# Out:
# --------------------------------------------------------
# NameError              Traceback (most recent call last)
# <ipython-input-1-9e38bd09aaf8> in <module>
# ----> 1 train_dataset = Dataset_Custom(
#       2     root_path='./',                 # folder path
#       3     data_path='econ.csv',           # your file with 333 rows
#       4     size=[36, 12, 24],              # 3 years in encoder, 1 year in labels, predict 24 months ahead
#       5     features='MS',                  # use all inputs but forecast only OT
#
# NameError: name 'Dataset_Custom' is not defined
